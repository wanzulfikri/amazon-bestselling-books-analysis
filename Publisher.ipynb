# %% [markdown]
# # What kind of book should we publish to get into the Amazon best sellers list?
#
# We are a new publisher looking to make our first published book a huge success. We focus on our first book because resources are limited and we can't afford to test the market by publishing multiple books and see what would sell the most. Another important detail is we're limited to publishing our e-books; hence, we won't be considering other medium such as physical books or audiobook.
#
# Our aim is somewhat modest and we are only looking to be included in the Amazon best sellers list. If we can be included in that list, we will be more likely to be included in other best sellers list such as the New York Times.
#
# In relation to the Amazon Book Best Sellers list, we want to answer the following questions:
# 1. Which genre is the most popular?
# 2. What is the average price of books?
# 3. How many reviews does a book receive on average? Does the average number of reviews change significantly depending on the genre?
# 4. How high is the rating a book receives on average? Does the average rating change significantly depending on the genre?
# 5. Are there any other factors aside from genre that makes a book popular?
#
# We'll start by answering the above plus some incidental questions found along the way; we will the follow up by formulating one or two book profiles that could potentially become best sellers.

# %% [markdown]
# ## Loading, Cleaning and Exploring the Data
#
# ### Load Data Set

# %%
import pandas as pd

amazon_books = pd.read_csv("Amazon_popular_books_dataset.csv")
print(amazon_books.shape)

# Display both head and tail of data frame
amazon_books
# Out:
# (2269, 40)
#             asin         ISBN10  answered_questions availability  \
# 0     0007350813     0007350813                   0    In Stock.
# 1     0007513763  9780007513765                   0    In Stock.
# 2     0008183988     0008183988                   0          NaN
# 3     0008305838     0008305838                   0    In Stock.
# 4     0008375526     0008375526                   0    In Stock.
# ...          ...            ...                 ...          ...
# 2264  B07P5BPVGM            NaN                   0          NaN
# 2265  B07P5JBCFL            NaN                   0          NaN
# 2266  B07NF7DFS2            NaN                   0          NaN
# 2267  B07P67N918            NaN                   0          NaN
# 2268  B07PFY8K2N            NaN                   0          NaN
#
#                                                   brand currency  \
# 0                                          Emily Brontë      USD
# 1                                          Drew Daywalt      USD
# 2                                      Bernard Cornwell      USD
# 3                                        David Walliams      USD
# 4                                       Caroline Hirons      USD
# ...                                                 ...      ...
# 2264                                        Jess Lourey      USD
# 2265  Heidi Murkoff (Author, Narrator), Meeghan Hola...      USD
# 2266  Clea Shearer (Author, Narrator), Joanna Teplin...      USD
# 2267  Lisa Jewell (Author), Tamaryn Payne (Narrator)...      USD
# 2268  Elton John (Author, Narrator), Taron Egerton (...      USD
#
#      date_first_available                                           delivery  \
# 0                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 1                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 2                     NaN  ["FREE delivery January 4 - 10 if you spend $2...
# 3                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 4                     NaN  ["FREE delivery Tuesday, December 28","Or fast...
# ...                   ...                                                ...
# 2264                  NaN                                                 []
# 2265                  NaN                                                 []
# 2266                  NaN                                                 []
# 2267                  NaN                                                 []
# 2268                  NaN                                                 []
#
#       department description  ...  upc                                   url  \
# 0            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0007350813
# 1            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0007513763
# 2            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0008183988
# 3            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0008305838
# 4            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0008375526
# ...          ...         ...  ...  ...                                   ...
# 2264         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07P5BPVGM
# 2265         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07P5JBCFL
# 2266         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07NF7DFS2
# 2267         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07P67N918
# 2268         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07PFY8K2N
#
#      video  video_count                                         categories  \
# 0      NaN            0   ["Books","Literature & Fiction","Genre Fiction"]
# 1      NaN            0  ["Books","Children's Books","Literature & Fict...
# 2      NaN            0   ["Books","Literature & Fiction","Genre Fiction"]
# 3      NaN            0  ["Books","Children's Books","Literature & Fict...
# 4      NaN            0  ["Books","Crafts, Hobbies & Home","Home Improv...
# ...    ...          ...                                                ...
# 2264   NaN            0  ["Books","Mystery, Thriller & Suspense","Thril...
# 2265   NaN            0  ["Books","Health, Fitness & Dieting","Women's ...
# 2266   NaN            0  ["Books","Crafts, Hobbies & Home","Home Improv...
# 2267   NaN            0  ["Books","Mystery, Thriller & Suspense","Thril...
# 2268   NaN            0  ["Books","Arts & Photography","Music","Musical...
#
#                                       best_sellers_rank         buybox_seller  \
# 0     [{"category":"Books / Literature & Fiction / H...                   NaN
# 1     [{"category":"Books / Children's Books / Liter...     VMG Books & Media
# 2     [{"category":"Books / Literature & Fiction / H...           Reuseaworld
# 3     [{"category":"Books / Children's Books / Liter...         Bahamut Media
# 4     [{"category":"Books / Health, Fitness & Dietin...  KathrynAshleyGallery
# ...                                                 ...                   ...
# 2264  [{"category":"Books / Mystery, Thriller & Susp...                   NaN
# 2265  [{"category":"Books / Health, Fitness & Dietin...                   NaN
# 2266  [{"category":"Audible Books & Originals / Home...                   NaN
# 2267  [{"category":"Audible Books & Originals / Myst...                   NaN
# 2268  [{"category":"Audible Books & Originals / Arts...                   NaN
#
#       image number_of_sellers colors
# 0       NaN               NaN    NaN
# 1       NaN               NaN    NaN
# 2       NaN               NaN    NaN
# 3       NaN               NaN    NaN
# 4       NaN               NaN    NaN
# ...     ...               ...    ...
# 2264    NaN               NaN    NaN
# 2265    NaN               NaN    NaN
# 2266    NaN               NaN    NaN
# 2267    NaN               NaN    NaN
# 2268    NaN               NaN    NaN
#
# [2269 rows x 40 columns]

# %% [markdown]
# 2269 rows of the data frame matched the data set [documentation](https://github.com/luminati-io/Amazon-popular-books-dataset#amazon-popular-books-dataset):
#
# > This Amazon dataset contains 2269 best-selling books.
#
# On the other hand, the documentation does not mention the number of columns. We should investigate the column names to make sure nothing odd happened when we loaded the data set.

# %%
# Show all columns
pd.DataFrame({'columns': amazon_books.columns})
# Out:
#                  columns
# 0                   asin
# 1                 ISBN10
# 2     answered_questions
# 3           availability
# 4                  brand
# 5               currency
# 6   date_first_available
# 7               delivery
# 8             department
# 9            description
# 10              discount
# 11                domain
# 12              features
# 13           final_price
# 14                format
# 15             image_url
# 16          images_count
# 17         initial_price
# 18           item_weight
# 19          manufacturer
# 20          model_number
# 21          plus_content
# 22    product_dimensions
# 23                rating
# 24         reviews_count
# 25          root_bs_rank
# 26             seller_id
# 27           seller_name
# 28             timestamp
# 29                 title
# 30                   upc
# 31                   url
# 32                 video
# 33           video_count
# 34            categories
# 35     best_sellers_rank
# 36         buybox_seller
# 37                 image
# 38     number_of_sellers
# 39                colors

# %% [markdown]
# ### Column Selection
#
# Observing the above results, the column names seems reasonable. Now, we'll need to select the relevant columns because even if keeping irrelevant columns don't have any impact in the results of our analysis, it does clutter the display and also slows down data processing and calculations.
#
# The documentation mentions that the following are the key columns:
#
# > Key data points included in this free dataset:
# > - ASIN
# > - ISBN10
# > - Categories
# > - Reviews count
# > - Avg. rating
# > - Number of sellers
# > - URL
# > - Image
# > - Final price
# > - Title
# > - Description
# > - Availability
#
# The above columns should be enough for the purpose of this project thus we will restrict our data frame to only those columns for now; we can always add the removed columns later if there's a need for them.
#
# | Full Name         | Column Name       |
# |:------------------|:------------------|
# | ASIN              | asin              |
# | ISBN10            | ISBN10            |
# | Categories        | categories        |
# | Reviews count     | reviews_count     |
# | Average rating    | rating            |
# | Number of sellers | number_of_sellers |
# | URL               | url               |
# | Image             | image             |
# | Final price       | final_price       |
# | Title             | title             |
# | Description       | description       |
# | Availability      | availability      |
# | Format            | format            |
# | Author            | brand             |
#
# We've also added the columns for Format and Author (which is called `brand` - odd, but makes sense because sometimes the book is authored collectively as an institution or publisher; and yes, authors are themselves brands in a way).

# %%
# Define the columns to keep
keep_cols = ['asin', 
             'ISBN10', 
             'categories', 
             'reviews_count', 
             'rating', 
             'number_of_sellers', 
             'url', 
             'image', 
             'final_price',
             'title',
             'description',
             'availability',
             'format',
             'brand'
            ]

# Review
amazon_books_updated = amazon_books[keep_cols]
amazon_books_updated.head()
# Out:
#          asin         ISBN10  \
# 0  0007350813     0007350813
# 1  0007513763  9780007513765
# 2  0008183988     0008183988
# 3  0008305838     0008305838
# 4  0008375526     0008375526
#
#                                           categories  reviews_count  \
# 0   ["Books","Literature & Fiction","Genre Fiction"]          13451
# 1  ["Books","Children's Books","Literature & Fict...          16628
# 2   ["Books","Literature & Fiction","Genre Fiction"]          11275
# 3  ["Books","Children's Books","Literature & Fict...          15520
# 4  ["Books","Crafts, Hobbies & Home","Home Improv...          10884
#
#                rating  number_of_sellers  \
# 0  4.6 out of 5 stars                NaN
# 1  4.8 out of 5 stars                NaN
# 2  4.8 out of 5 stars                NaN
# 3  4.8 out of 5 stars                NaN
# 4  4.8 out of 5 stars                NaN
#
#                                     url image  final_price  \
# 0  https://www.amazon.com/dp/0007350813   NaN         3.99
# 1  https://www.amazon.com/dp/0007513763   NaN        12.08
# 2  https://www.amazon.com/dp/0008183988   NaN          NaN
# 3  https://www.amazon.com/dp/0008305838   NaN        20.43
# 4  https://www.amazon.com/dp/0008375526   NaN        28.89
#
#                                                title description availability  \
# 0               Wuthering Heights (Collins Classics)         NaN    In Stock.
# 1                          THE DAYS THE CRAYONS QUIT         NaN    In Stock.
# 2        War Lord: Book 13 (The Last Kingdom Series)         NaN          NaN
# 3  Code Name Bananas: The hilarious and epic new ...         NaN    In Stock.
# 4  Skincare: The award-winning ultimate no-nonsen...         NaN    In Stock.
#
#                                               format             brand
# 0  [{"name":"Kindle","price":"$0.99","url":"/Wuth...      Emily Brontë
# 1  [{"name":"Kindle","price":"$10.99","url":"/Day...      Drew Daywalt
# 2  [{"name":"Kindle","price":"$11.99","url":"/War...  Bernard Cornwell
# 3  [{"name":"Paperback","price":"$24.78","url":"/...    David Walliams
# 4  [{"name":"Kindle","price":"$16.99","url":"/Ski...   Caroline Hirons

# %% [markdown]
# ### Another Round of Column Selection
#
# The previous column selection is mostly done to retrieve plausible columns for the analysis. Upon closer inspection, there are some columns I would like to remove:
#
# | Full Name    | Column Name  | Reason for Removal                                                                                                                                                                                                                                                                                                                                                                                         |
# |:-------------|:-------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | ASIN         | asin         | The [Amazon Standard Identification Number](https://en.wikipedia.org/wiki/Amazon_Standard_Identification_Number) (ASIN) is not required. It's sufficient to identify a book by its title.                                                                                                                                                                                                                  |
# | ISBN         | ISBN10       | Similar to the reason for ASIN removal, the [International Standard Book Number](https://en.wikipedia.org/wiki/ISBN) (ISBN) is not required.                                                                                                                                                                                                                                                               |
# | URL          | url          | The url or link to the Amazon page for the book is not necessary. Our analysis doesn't cover anything that looks into the exact url or the page the url links to.                                                                                                                                                                                                                                          |
# | Image        | image        | The image of the book is not needed. It could be useful, but it requires different (and potentially more complicated) data analysis methods which are beyond the scope of this project. A worthy candidate for investigation in our next project.                                                                                                                                                          |
# | Description  | description  | Similar to book image, this could be useful but can be too complicated to analyse for the purpose of this project.                                                                                                                                                                                                                                                                                         |
# | Availability | availability | We are not concerned with a book's stock availability on Amazon; if the book is included in the best seller list, it's good enough whether it's available or not. Other than that, stock availability data is dynamic and the data set is just a snapshot of a book's availability when the data was collected; we'll need a time series data set of availability if we want to use the data for analysis. |

# %%
# Define the columns to remove
remove_cols =   [
                 'asin', 
                 'ISBN10', 
                 'url', 
                 'image', 
                 'description',
                 'availability',
                 ]

# Remove the columns
amazon_books_updated = amazon_books_updated.drop(columns=remove_cols)

# Review
amazon_books_updated.head()
# Out:
#                                           categories  reviews_count  \
# 0   ["Books","Literature & Fiction","Genre Fiction"]          13451
# 1  ["Books","Children's Books","Literature & Fict...          16628
# 2   ["Books","Literature & Fiction","Genre Fiction"]          11275
# 3  ["Books","Children's Books","Literature & Fict...          15520
# 4  ["Books","Crafts, Hobbies & Home","Home Improv...          10884
#
#                rating  number_of_sellers  final_price  \
# 0  4.6 out of 5 stars                NaN         3.99
# 1  4.8 out of 5 stars                NaN        12.08
# 2  4.8 out of 5 stars                NaN          NaN
# 3  4.8 out of 5 stars                NaN        20.43
# 4  4.8 out of 5 stars                NaN        28.89
#
#                                                title  \
# 0               Wuthering Heights (Collins Classics)
# 1                          THE DAYS THE CRAYONS QUIT
# 2        War Lord: Book 13 (The Last Kingdom Series)
# 3  Code Name Bananas: The hilarious and epic new ...
# 4  Skincare: The award-winning ultimate no-nonsen...
#
#                                               format             brand
# 0  [{"name":"Kindle","price":"$0.99","url":"/Wuth...      Emily Brontë
# 1  [{"name":"Kindle","price":"$10.99","url":"/Day...      Drew Daywalt
# 2  [{"name":"Kindle","price":"$11.99","url":"/War...  Bernard Cornwell
# 3  [{"name":"Paperback","price":"$24.78","url":"/...    David Walliams
# 4  [{"name":"Kindle","price":"$16.99","url":"/Ski...   Caroline Hirons

# %% [markdown]
# The final list of columns will be the following:
#
# | Full Name         | Column Name       |
# |:------------------|:------------------|
# | Categories        | categories        |
# | Reviews count     | reviews_count     |
# | Average rating    | rating            |
# | Number of sellers | number_of_sellers |
# | Final price       | final_price       |
# | Title             | title             |
# | Format            | format            |
# | Author            | brand             |

# %% [markdown]
# ### Handling missing values
#
# Let's check for missing values.

# %%
# Show the number of missing values per column
amazon_books_updated.isnull().sum()
# Out:
# categories              0
# reviews_count           0
# rating                  0
# number_of_sellers    2265
# final_price           877
# title                   0
# format                 96
# brand                   1
# dtype: int64

# %% [markdown]
# It seems that the number of sellers, final price, format, and brand columns have missing values. The first two, especially  number of sellers, have startling number of missing values. Next, I'll go through each column one by one to evaluate how to handle them.
#
# **Missing values in the number of sellers column**
#
# There's a significant number of missing values in this column. Interesting enough, there are 3 rows with a value.

# %%
# Show frequency of values in number_of_sellers
amazon_books_updated['number_of_sellers'].value_counts()

# Show rows which has no missing values in number_of_sellers
amazon_books_updated[amazon_books_updated['number_of_sellers'].notnull()]
# Out:
#                                              categories  reviews_count  \
# 664   ["Books","Humor & Entertainment","Puzzles & Ga...          37782
# 1194  ["Books","Self-Help","Relationships","Love & R...          15377
# 2029  ["Toys & Games","Learning & Education","Electr...          18477
# 2177             ["Books","Calendars","Animals","Dogs"]          11249
#
#                   rating  number_of_sellers  final_price  \
# 664   4.9 out of 5 stars               94.0        27.93
# 1194  4.7 out of 5 stars               19.0         8.01
# 2029  4.8 out of 5 stars                4.0        17.99
# 2177  4.8 out of 5 stars                2.0        16.99
#
#                                                   title format  \
# 664              Player's Handbook (Dungeons & Dragons)    NaN
# 1194  Knock Knock What I Love about You Fill in the ...    NaN
# 2029                    VTech Musical Rhymes Book, Pink    NaN
# 2177   Pooping Pooches White Elephant Gag Gift Calendar    NaN
#
#                      brand
# 664   Wizards of the Coast
# 1194           Knock Knock
# 2029                 VTech
# 2177       Pooping Pooches

# %% [markdown]
# It doesn't seem that we can glean anything important from the available values for number of sellers. Doing the work ourself by filling in the number of sellers is not an option because we do not know exactly when the data was collected; even if we do know, it's unclear whether it's possible to find past data for the known date. Our only option is to drop the number of sellers column though not reluctantly because it is not too important for our analysis.

# %%
amazon_books_updated.drop(columns=['number_of_sellers'], inplace=True)
# Verify column has been dropped
pd.DataFrame({"columns": amazon_books_updated.columns})
# Out:
#          columns
# 0     categories
# 1  reviews_count
# 2         rating
# 3    final_price
# 4          title
# 5         format
# 6          brand

# %% [markdown]
# **Missing values in the final price and format columns**
#
# We put both the final price and format columns together in this section because they are actually related. Let's see what we mean by that:

# %%
# Print the frequency of values in both the final price and format columns
print(amazon_books_updated['final_price'].value_counts(dropna=False))

# Be ready for an eyesore
print(amazon_books_updated['format'].value_counts(dropna=False).head())
# Out:
# NaN      877
# 9.99      25
# 6.99      24
# 8.99      23
# 15.99     21
#         ...
# 17.26      1
# 25.01      1
# 21.06      1
# 58.88      1
# 9.48       1
# Name: final_price, Length: 733, dtype: int64
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                96
# [{"name":"Kindle","price":"$0.00","url":"/Picture-Dorian-Gray-AmazonClassics-ebook/dp/B071HDXV91"},{"name":"Hardcover","price":"","url":"/Picture-Dorian-Penguin-Clothbound-Classics/dp/0141442468"},{"name":"Paperback","price":"$3.88","url":"/Picture-Dorian-Gray-Oscar-Wilde/dp/1548296740"},{"name":"Mass Market Paperback","price":"$6.46","url":"/Picture-Dorian-Gray-Tor-Classics/dp/0812567110"},{"name":"MP3 CD","price":"","url":"/Picture-Dorian-Gray-Classic-Collection/dp/1501288202"},{"name":"Digital","price":"","url":"/The-Picture-of-Dorian-Gray/dp/0007219008"}]                                                                                                                                               4
# [{"name":"Kindle","price":"$0.49","url":"/Art-War-Sun-Tzu-ebook/dp/B096G2Q2T6"},{"name":"Hardcover","price":"$9.44","url":"/Art-War-Chump-Change/dp/1640320164"},{"name":"Paperback","price":"$3.55","url":"/Art-War-Sun-Tzu/dp/3903352608"},{"name":"Mass Market Paperback","price":"$7.68","url":"/Art-War-Sun-Tzu/dp/1590302257"},{"name":"Preloaded Digital Audio Player","price":"$39.99","url":"/Art-War-Library-Sun-tzu/dp/1598958445"}]                                                                                                                                                                                                                                                                                     3
# [{"name":"Kindle","price":"$12.99","url":"/Immortal-Life-Henrietta-Lacks-ebook/dp/B00338QENI"},{"name":"Audiobook","price":"Audiobook $0.00","url":"/Immortal-Life-Henrietta-Lacks/dp/B0036UZCRM"},{"name":"Hardcover","price":"$14.32","url":"/Immortal-Life-Henrietta-Lacks/dp/1400052173"},{"name":"Paperback","price":"$12.10","url":"/Immortal-Life-Henrietta-Lacks/dp/1400052181"},{"name":"Audio CD","price":"$23.74","url":"/Immortal-Life-Henrietta-Lacks/dp/0451486315"}]                                                                                                                                                                                                                                                 3
# [{"name":"Kindle","price":"$0.00","url":"/Christmas-Carol-AmazonClassics-Charles-Dickens-ebook/dp/B071ZKZBWR"},{"name":"Audiobook","price":"Audiobook $0.00","url":"/A-Christmas-Carol-Charles-Dickens-audiobook/dp/B07JQ28G6X"},{"name":"Paperback","price":"$2.99","url":"/Christmas-Carol-Dover-Thrift-Editions/dp/0486268659"},{"name":"Loose Leaf","price":"$22.49","url":"/Christmas-carol-Charles-Dickens/dp/0717246108"},{"name":"Mass Market Paperback","price":"$3.95","url":"/Christmas-Carol-Bantam-Classics/dp/0553212443"},{"name":"Audio CD","price":"$39.61","url":"/Christmas-Carol-Charles-Dickens/dp/1400086035"},{"name":"Multimedia CD","price":"$51.95","url":"/Christmas-Carol-Audio-CD/dp/1413010970"}]     3
# Name: format, dtype: int64

# %% [markdown]
# Note that the format column also has prices in them but each price is linked to a certain format. This means that a book might have multiple prices depending on its format.
#
# Other than that, the values in the final price column is as expected at least on a cursory look, but the values in the format column needs further inspection. Before that, we need to do some data conversion for the format column because even though the above looks like a list, it is actually a string. Converting all the values into a list is our next step.

# %%
import ast
import numpy as np

'''
**Convert each value that is not null into a list**

`ast.literal_eval` evaluates and converts the literal string into the appropriate Python object. 

The [documentation](https://docs.python.org/3/library/ast.html#ast.literal_eval) mentioned that it is safe-ish; it prevents Python code from being called but depending on the input, it's possible to trigger memory or C-stack exhaustion.

We trust the collector of the data set enough to use `ast.literal_eval` in spite of the potential attack.
'''
amazon_books_updated['format'] = amazon_books_updated['format'].apply(lambda x: ast.literal_eval(x) if not pd.isna(x) else np.nan)

# Making sure that all values in format is either a list or a null value
print("Formats are either list or nulls: {}".format(amazon_books_updated['format'].apply(lambda x: type(x) is list or x is np.nan).all()))

# Verify if the number of nulls is still the same
amazon_books_updated['format'].isnull().sum()
# Out:
# Formats are either list or nulls: True
# 96

# %% [markdown]
# Next, let's explore the possible values for the format name and price.

# %%
'''
The value in the format column is a list containing dictionaries. 

In each list is a dictionary that follows the following structure:
{
    "name": "Format",
    "price": "$0.00",
    "url": "/url/to/the/book/page/on/Amazon"
}

We would like to extract the name and price for each book. 

''' 

price_set = set()
format_set = set()

not_null_format = amazon_books_updated[amazon_books_updated['format'].notnull()]['format']

# Loop through the rows with no missing formats and add to the corresponding sets
for formats in not_null_format:
    for book_format in formats:
        format_name = book_format['name']
        price = book_format['price']
        
        format_set.add(format_name)
        price_set.add(price)

        
# Prepare for display
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"

format_df = pd.DataFrame({"format": list(format_set)})
display(format_df)

price_df = pd.DataFrame({"price": list(price_set)})
price_df
# Out:
#                              format
# 0                            Comics
# 1                        Board book
# 2                   Book Supplement
# 3                             Cards
# 4                            MP3 CD
# 5                  Textbook Binding
# 6                 Perfect Paperback
# 7                      Spiral-bound
# 8          School & Library Binding
# 9                      Plastic Comb
# 10                       Ring-bound
# 11                      Sheet music
# 12                  Library Binding
# 13            Mass Market Paperback
# 14                           Kindle
# 15                          Digital
# 16                              Toy
# 17            Single Issue Magazine
# 18                         Audio CD
# 19                      Vinyl Bound
# 20   Preloaded Digital Audio Player
# 21                              Map
# 22         Audio CD Library Binding
# 23  Kindle Edition with Audio/Video
# 24              Accessory with book
# 25                  Audio, Cassette
# 26                         Rag Book
# 27                       Flexibound
# 28                   Product Bundle
# 29                        Audiobook
# 30                    Multimedia CD
# 31                    Leather Bound
# 32                        Paperback
# 33                       Loose Leaf
# 34                        Hardcover
# 35              Kindle & comiXology
#        price
# 0
# 1     $15.49
# 2     $25.92
# 3     $44.99
# 4     $10.97
# ...      ...
# 1398  $16.22
# 1399   $2.72
# 1400  $19.98
# 1401  $23.63
# 1402  $10.57
#
# [1403 rows x 1 columns]

# %% [markdown]
# One thing for certain is we didn't expect the variety of book formats (which must be obvious to everyone else but not us). This introduces slight complexity on our part because we need to select the format that best represents our more general book format: physical book and e-book.
#
# On the other hand, the values for price looks reasonable except for the empty value.
#
# Let's identify which book format to keep.
#
# **Identifying relevant formats**
#
# Physical books on Amazon can come in many formats. After reviewing the books we intend to publish, we decided to focus on the following physical formats: paperback and hardcover. For e-books, the obvious choice would be Kindle and we ignore its derivatives which are Kindle & comixology and Kindle Edition with Audio/Video.
#
# We've pruned the format list to only represent what we intend to publish:
#
# | Format Name           | Definition                                                                                                                                                                                                                                                                                                            |
# |:----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Paperback             | A book with thick paper or paperboard cover. To contrast with the mass market paperback, a paperback is also called "trade paperback" and is regarded as being higher in quality.                                                                                                                                     |
# | Perfect Paperback     | "Perfect" might be a misnomer here depending on your knowledge of book publication. A perfect paperback is not about the quality of the paperback but the kind of binding used. Perfect binding relies solely on adhesive and does not use any stitches.                                                                         |
# | Mass Market Paperback | A mass market paperback is similar to a "trade" paperback, but it tends to be smaller and less durable. It's also generally cheaper since it's intended to be produced "in mass". This format is generally used when publishing very popular books in order to make it accessible, mostly price-wise, to most people. |
# | Hardcover             | A book with rigid/hard protective covers. A book will typically have a hardcover format which are published early in the publication cycle and only for a limited amount of time. After sales are slower, publisher of the hardcover book normally transition to the cheaper paperback format to reinvigorate sales.  |
# | Kindle                | An e-book meant for reading with an Amazon Kindle.                                                                                                                                                                                                                                                                    |
#
# You can find some references on book formats in the <a href="#References">References</a> section.
#
# **Keep only the relevant book formats in the data set**

# %%
keep_format = ['Paperback', 'Kindle', 'Perfect Paperback', 'Mass Market Paperback', 'Hardcover']

def keep_specific_format(format_list, format_to_keep):
    if format_list == np.nan:
        return format_list
    for f_dict in format_list:
        if f_dict['name'] == format_to_keep:
            return f_dict['price']

def keep_paperback_hardcover_kindle(row):
#   print(row['format'])
    book_formats = row['format']
    if book_formats is np.nan:
         return row
    for format in book_formats:
        name = format['name']
        price = format['price']
        if name in keep_format:
            split_name = name.split(' ')
            snakecase_name = "_".join(split_name).lower()
            row["{}_price".format(snakecase_name)] = price
    return row

amazon_books_updated = amazon_books_updated.apply(keep_paperback_hardcover_kindle, axis=1)
amazon_books_updated.head()
# Out:
#               brand                                         categories  \
# 0      Emily Brontë   ["Books","Literature & Fiction","Genre Fiction"]
# 1      Drew Daywalt  ["Books","Children's Books","Literature & Fict...
# 2  Bernard Cornwell   ["Books","Literature & Fiction","Genre Fiction"]
# 3    David Walliams  ["Books","Children's Books","Literature & Fict...
# 4   Caroline Hirons  ["Books","Crafts, Hobbies & Home","Home Improv...
#
#    final_price                                             format  \
# 0         3.99  [{'name': 'Kindle', 'price': '$0.99', 'url': '...
# 1        12.08  [{'name': 'Kindle', 'price': '$10.99', 'url': ...
# 2          NaN  [{'name': 'Kindle', 'price': '$11.99', 'url': ...
# 3        20.43  [{'name': 'Paperback', 'price': '$24.78', 'url...
# 4        28.89  [{'name': 'Kindle', 'price': '$16.99', 'url': ...
#
#   hardcover_price kindle_price mass_market_paperback_price paperback_price  \
# 0          $10.99        $0.99                       $4.95             NaN
# 1           $9.19       $10.99                         NaN             NaN
# 2          $18.29       $11.99                         NaN             NaN
# 3             NaN          NaN                         NaN          $24.78
# 4             NaN       $16.99                         NaN             NaN
#
#   perfect_paperback_price              rating  reviews_count  \
# 0                     NaN  4.6 out of 5 stars          13451
# 1                     NaN  4.8 out of 5 stars          16628
# 2                     NaN  4.8 out of 5 stars          11275
# 3                     NaN  4.8 out of 5 stars          15520
# 4                     NaN  4.8 out of 5 stars          10884
#
#                                                title
# 0               Wuthering Heights (Collins Classics)
# 1                          THE DAYS THE CRAYONS QUIT
# 2        War Lord: Book 13 (The Last Kingdom Series)
# 3  Code Name Bananas: The hilarious and epic new ...
# 4  Skincare: The award-winning ultimate no-nonsen...

# %% [markdown]
# It seems that the information from the format column is much richer than the final price column. Another thing we recently noticed is we don't have an idea which format the final price is referring to. This highlights another problem: formats are needed because we're only interested in books that were published at least as a hardcover, paperback, or an e-book; without the format, we risk addding non-representative books into our analysis.
#
# Because of the above stated reasons, we are considering removing the final price column and also any books with missing formats. Let's investigate those books with no formats first before removing anything.

# %%
# Define a simple function that prints the length of two data frames.
# It also prints the percentage of one length in relation to another length
def print_length_and_percentage(subset, df, noun="rows"):
    subset_nrows = subset.shape[0]
    df_nrows     = df.shape[0]
    print("Number of rows in data set: {}".format(df_nrows))
    print("Number of {}: {}".format(noun, subset_nrows))
    print("Percentage of total data set: {:.2%}".format(subset_nrows/df_nrows))

# Get books with missing formats
no_formats = amazon_books_updated[amazon_books_updated['format'].isnull()]

display(no_formats)

# Get the percentage of books with missing formats; needed to decide whether to drop them
print("Number of books with missing formats: {}".format(no_formats.shape[0]))
print("Percentage of total data set: {:.2%}".format(no_formats.shape[0]/amazon_books_updated.shape[0]))
# Out:
# Empty DataFrame
# Columns: [brand, categories, format, hardcover_price, kindle_price, mass_market_paperback_price, paperback_price, perfect_paperback_price, rating, reviews_count, title]
# Index: []
# Number of books with missing formats: 0
# Percentage of total data set: 0.00%

# %% [markdown]
# After further consideration, we decided to remove books with no formats for the following reasons:
# 1. We could use the book prices in the current year (2022) but that still requires resources (mostly time) we can't afford to expend for this mostly exploratory project. We might consider doing so if there are only a few books, but 96 books are relatively numerous considering our limited resources.
# 2. We gave a cursory look at the details of some of the books and we realised that some of them are not representative of what we want to publish. As seen in the table above, at least 5 of the 10 books are not hardcover, paperback, nor e-books. It seems that a signficant portion of them are books for children which come in child-friendly formats such as board book, musical rhyme book, and activity workbook.
# 3. Although removing around 4 per cent of all books in the data set is not ideal, we're confident that the impact is potentially not significant considering that not all 96 books are representative of the books we're looking for.

# %%
# Remove books with no formats 
amazon_books_updated.drop(index=no_formats.index, inplace=True)

# At the same time, drop the final_price
amazon_books_updated.drop(columns=['final_price'], inplace=True)

amazon_books_updated.head()
# Out:
#               brand                                         categories  \
# 0      Emily Brontë   ["Books","Literature & Fiction","Genre Fiction"]
# 1      Drew Daywalt  ["Books","Children's Books","Literature & Fict...
# 2  Bernard Cornwell   ["Books","Literature & Fiction","Genre Fiction"]
# 3    David Walliams  ["Books","Children's Books","Literature & Fict...
# 4   Caroline Hirons  ["Books","Crafts, Hobbies & Home","Home Improv...
#
#                                               format hardcover_price  \
# 0  [{'name': 'Kindle', 'price': '$0.99', 'url': '...          $10.99
# 1  [{'name': 'Kindle', 'price': '$10.99', 'url': ...           $9.19
# 2  [{'name': 'Kindle', 'price': '$11.99', 'url': ...          $18.29
# 3  [{'name': 'Paperback', 'price': '$24.78', 'url...             NaN
# 4  [{'name': 'Kindle', 'price': '$16.99', 'url': ...             NaN
#
#   kindle_price mass_market_paperback_price paperback_price  \
# 0        $0.99                       $4.95             NaN
# 1       $10.99                         NaN             NaN
# 2       $11.99                         NaN             NaN
# 3          NaN                         NaN          $24.78
# 4       $16.99                         NaN             NaN
#
#   perfect_paperback_price              rating  reviews_count  \
# 0                     NaN  4.6 out of 5 stars          13451
# 1                     NaN  4.8 out of 5 stars          16628
# 2                     NaN  4.8 out of 5 stars          11275
# 3                     NaN  4.8 out of 5 stars          15520
# 4                     NaN  4.8 out of 5 stars          10884
#
#                                                title
# 0               Wuthering Heights (Collins Classics)
# 1                          THE DAYS THE CRAYONS QUIT
# 2        War Lord: Book 13 (The Last Kingdom Series)
# 3  Code Name Bananas: The hilarious and epic new ...
# 4  Skincare: The award-winning ultimate no-nonsen...

# %% [markdown]
# With the removal finished, let's complete the handling of missing values for the final price and format columns by removing books which are neither hardcover, paperback, nor e-book. There is around 30 books that has that criteria which accounts for approximately 1.5% of the whole data set. We're fine with removing them because they're certainly not representative of the books we want.

# %%
# Create a boolean mask to filter only those books with no hardcover, paperback, or e-book format
# hpe - hardcover, paperback, e-book
mask_not_hpe = amazon_books_updated[['hardcover_price', 'mass_market_paperback_price', 'paperback_price', 'perfect_paperback_price', 'kindle_price']].isnull().all(axis=1)
books_no_hpe = amazon_books_updated[mask_not_hpe]

print("Books with no hardcover, paperback, or e-book: {}".format(books_no_hpe.shape[0]))
print("Percentage of total data set: {:.2%}".format(books_no_hpe.shape[0]/amazon_books_updated.shape[0]))

# Remove the books
amazon_books_updated.drop(index=books_no_hpe.index, inplace=True)

amazon_books_updated.head()
# Out:
# Books with no hardcover, paperback, or e-book: 32
# Percentage of total data set: 1.47%
#               brand                                         categories  \
# 0      Emily Brontë   ["Books","Literature & Fiction","Genre Fiction"]
# 1      Drew Daywalt  ["Books","Children's Books","Literature & Fict...
# 2  Bernard Cornwell   ["Books","Literature & Fiction","Genre Fiction"]
# 3    David Walliams  ["Books","Children's Books","Literature & Fict...
# 4   Caroline Hirons  ["Books","Crafts, Hobbies & Home","Home Improv...
#
#                                               format hardcover_price  \
# 0  [{'name': 'Kindle', 'price': '$0.99', 'url': '...          $10.99
# 1  [{'name': 'Kindle', 'price': '$10.99', 'url': ...           $9.19
# 2  [{'name': 'Kindle', 'price': '$11.99', 'url': ...          $18.29
# 3  [{'name': 'Paperback', 'price': '$24.78', 'url...             NaN
# 4  [{'name': 'Kindle', 'price': '$16.99', 'url': ...             NaN
#
#   kindle_price mass_market_paperback_price paperback_price  \
# 0        $0.99                       $4.95             NaN
# 1       $10.99                         NaN             NaN
# 2       $11.99                         NaN             NaN
# 3          NaN                         NaN          $24.78
# 4       $16.99                         NaN             NaN
#
#   perfect_paperback_price              rating  reviews_count  \
# 0                     NaN  4.6 out of 5 stars          13451
# 1                     NaN  4.8 out of 5 stars          16628
# 2                     NaN  4.8 out of 5 stars          11275
# 3                     NaN  4.8 out of 5 stars          15520
# 4                     NaN  4.8 out of 5 stars          10884
#
#                                                title
# 0               Wuthering Heights (Collins Classics)
# 1                          THE DAYS THE CRAYONS QUIT
# 2        War Lord: Book 13 (The Last Kingdom Series)
# 3  Code Name Bananas: The hilarious and epic new ...
# 4  Skincare: The award-winning ultimate no-nonsen...

# %% [markdown]
# **Checkpoint**
#
# We added a lot of changes to the data set so it's a good idea to review those before continuing further.
#
# We initially set out to handle missing values. The first thing we did was removing the number of sellers column. Next, we looked into the missing values for the final price and format columns; we noticed that we did not need the final price column thus we removed it. We also decided to remove books with missing format values and our reasons are partly resource limitations and partly non-representativeness.
#
# Let us review the current missing values for all columns.

# %%
# Show the number of missing values per column
amazon_books_updated.isnull().sum()
# Out:
# brand                             0
# categories                        0
# format                            0
# hardcover_price                 762
# kindle_price                    256
# mass_market_paperback_price    1413
# paperback_price                 740
# perfect_paperback_price        2138
# rating                            0
# reviews_count                     0
# title                             0
# dtype: int64

# %% [markdown]
# Aside from the prices columns, all columns do not have missing values. The missing values for the prices columns are expected because not all books will have all five formats. This means that when we analyse price, depending on the number of missing values, the findings might be more limited compared to the findings for the other columns i.e. the more data points the better. Nonetheless, we're comfortable with that caveat and we will still keep the prices columns.
#
# ### Handling Duplicate Books
#
# Our next task is to look for duplicate books. We can simply look if there are books with the same title.

# %%
duplicate_books = amazon_books_updated[amazon_books_updated.duplicated(subset=['title'])]
                                       
print_length_and_percentage(duplicate_books, amazon_books_updated, "duplicate books")
# Out:
# Number of rows in data set: 2141
# Number of duplicate books: 661
# Percentage of total data set: 30.87%

# %% [markdown]
# There are 661 duplicate books which amounts to around 31% of the whole data set. That's quite a lot.
#
# Let's zoom in a bit to inspect the duplicates.

# %%
all_duplicated_books = amazon_books_updated[amazon_books_updated.duplicated(subset=['title'], keep=False)].sort_values(by=['title'])
all_duplicated_books.head(25)
# Out:
#                                                   brand  \
# 101                                  Jordan B. Peterson
# 269                                  Jordan B. Peterson
# 2198  Jordan B. Peterson (Author, Narrator), Norman ...
# 416                                       George Orwell
# 418                                       George Orwell
# 786                                       George Orwell
# 1760                                      George Orwell
# 1694  George Orwell (Author), Charlton Griffin (Narr...
# 1749  George Orwell (Author), Benjamin May (Narrator...
# 747                                  Matthew R. Kratter
# 1466  Matthew R. Kratter (Author), Mike Norgaard (Na...
# 299                                      Diana Gabaldon
# 397                                      Diana Gabaldon
# 2241  Charles Dickens (Author), Derek Miller (Narrat...
# 1274                                    Charles Dickens
# 2196  Sarah J. Maas (Author), Jennifer Ikeda (Narrat...
# 1248                                      Sarah J. Maas
# 2016  Sarah J. Maas (Author), Jennifer Ikeda (Narrat...
# 1099                                     David Baldacci
# 1098                                     David Baldacci
# 2072                                        Amor Towles
# 123                                         Amor Towles
# 565                                         Amor Towles
# 2078  Amor Towles (Author), Nicholas Guy Smith (Narr...
# 1514  Isabel Allende (Author), Edoardo Ballerini (Na...
#
#                                              categories  \
# 101   ["Books","Business & Money","Job Hunting & Car...
# 269   ["Books","Health, Fitness & Dieting","Psycholo...
# 2198  ["Books","Health, Fitness & Dieting","Psycholo...
# 416    ["Books","Literature & Fiction","Genre Fiction"]
# 418    ["Books","Literature & Fiction","Genre Fiction"]
# 786    ["Books","Literature & Fiction","Genre Fiction"]
# 1760  ["Books","Politics & Social Sciences","Social ...
# 1694  ["Books","Literature & Fiction","Genre Fiction...
# 1749  ["Books","Science Fiction & Fantasy","Science ...
# 747            ["Books","Business & Money","Investing"]
# 1466  ["Books","Business & Money","Investing","Stocks"]
# 299     ["Books","Science Fiction & Fantasy","Fantasy"]
# 397    ["Books","Literature & Fiction","Genre Fiction"]
# 2241  ["Books","Literature & Fiction","Genre Fiction...
# 1274   ["Books","Literature & Fiction","Genre Fiction"]
# 2196  ["Books","Teen & Young Adult","Literature & Fi...
# 1248    ["Books","Science Fiction & Fantasy","Fantasy"]
# 2016  ["Books","Teen & Young Adult","Literature & Fi...
# 1099  ["Books","Literature & Fiction","Action & Adve...
# 1098  ["Books","Literature & Fiction","Action & Adve...
# 2072  ["Books","Mystery, Thriller & Suspense","Thril...
# 123   ["Books","Mystery, Thriller & Suspense","Thril...
# 565    ["Books","Literature & Fiction","Genre Fiction"]
# 2078  ["Books","Literature & Fiction","Genre Fiction...
# 1514  ["Books","Literature & Fiction","Genre Fiction...
#
#                                                  format hardcover_price  \
# 101   [{'name': 'Kindle', 'price': '$13.99', 'url': ...          $14.99
# 269   [{'name': 'Kindle', 'price': '$13.99', 'url': ...             NaN
# 2198  [{'name': 'Kindle', 'price': '$13.99', 'url': ...          $14.99
# 416   [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $10.99
# 418   [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $10.99
# 786   [{'name': 'Kindle', 'price': '$9.99', 'url': '...             NaN
# 1760  [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $10.99
# 1694  [{'name': 'Kindle', 'price': '$0.90', 'url': '...          $10.99
# 1749  [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $10.99
# 747   [{'name': 'Kindle', 'price': '$0.00', 'url': '...             NaN
# 1466  [{'name': 'Kindle', 'price': '$0.00', 'url': '...             NaN
# 299   [{'name': 'Kindle', 'price': '$9.99', 'url': '...             NaN
# 397   [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $28.69
# 2241  [{'name': 'Kindle', 'price': '$0.49', 'url': '...           $9.95
# 1274  [{'name': 'Kindle', 'price': '$0.00', 'url': '...          $18.61
# 2196  [{'name': 'Kindle', 'price': '$6.65', 'url': '...          $19.59
# 1248  [{'name': 'Kindle', 'price': '$6.65', 'url': '...          $19.59
# 2016  [{'name': 'Kindle', 'price': '$6.65', 'url': '...          $19.59
# 1099  [{'name': 'Kindle', 'price': '$11.99', 'url': ...          $13.99
# 1098  [{'name': 'Kindle', 'price': '$11.99', 'url': ...             NaN
# 2072  [{'name': 'Audiobook', 'price': 'Audiobook $0....          $14.76
# 123   [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $14.76
# 565   [{'name': 'Kindle', 'price': '$9.99', 'url': '...             NaN
# 2078  [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $14.76
# 1514  [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $14.04
#
#      kindle_price mass_market_paperback_price paperback_price  \
# 101        $13.99                         NaN             NaN
# 269        $13.99                         NaN          $17.63
# 2198       $13.99                         NaN          $17.63
# 416         $9.99                         NaN          $11.63
# 418         $9.99                       $7.48             NaN
# 786         $9.99                       $7.48          $11.63
# 1760        $9.99                       $7.48          $11.63
# 1694        $0.90                       $7.48           $8.75
# 1749        $9.99                       $7.48          $11.63
# 747         $0.00                         NaN             NaN
# 1466        $0.00                         NaN           $6.99
# 299         $9.99                       $8.49          $15.99
# 397         $9.99                         NaN          $15.99
# 2241        $0.49                       $3.95           $3.58
# 1274        $0.00                       $3.95             NaN
# 2196        $6.65                         NaN          $10.80
# 1248        $6.65                         NaN             NaN
# 2016        $6.65                         NaN          $10.80
# 1099       $11.99                         NaN             NaN
# 1098       $11.99                         NaN          $11.99
# 2072          NaN                         NaN           $9.34
# 123         $9.99                         NaN             NaN
# 565         $9.99                         NaN           $9.34
# 2078        $9.99                         NaN           $9.34
# 1514        $9.99                      $17.11          $14.49
#
#      perfect_paperback_price              rating  reviews_count  \
# 101                      NaN  4.8 out of 5 stars          43801
# 269                      NaN  4.8 out of 5 stars          43801
# 2198                     NaN  4.8 out of 5 stars          43801
# 416                      NaN  4.7 out of 5 stars          55581
# 418                      NaN  4.7 out of 5 stars          55581
# 786                      NaN  4.7 out of 5 stars          55581
# 1760                     NaN  4.7 out of 5 stars          55581
# 1694                     NaN  4.7 out of 5 stars          55581
# 1749                     NaN  4.7 out of 5 stars          55582
# 747                      NaN  4.5 out of 5 stars          13067
# 1466                     NaN  4.5 out of 5 stars          13067
# 299                      NaN  4.8 out of 5 stars          13908
# 397                      NaN  4.8 out of 5 stars          13908
# 2241                     NaN  4.7 out of 5 stars          12865
# 1274                     NaN  4.7 out of 5 stars          12865
# 2196                     NaN  4.7 out of 5 stars          35943
# 1248                     NaN  4.7 out of 5 stars          35941
# 2016                     NaN  4.7 out of 5 stars          35943
# 1099                     NaN  4.4 out of 5 stars          21250
# 1098                     NaN  4.4 out of 5 stars          21250
# 2072                     NaN  4.6 out of 5 stars          37254
# 123                      NaN  4.6 out of 5 stars          37254
# 565                      NaN  4.6 out of 5 stars          37254
# 2078                     NaN  4.6 out of 5 stars          37254
# 1514                     NaN  4.4 out of 5 stars          10398
#
#                                                   title
# 101             12 Rules for Life: An Antidote to Chaos
# 269             12 Rules for Life: An Antidote to Chaos
# 2198            12 Rules for Life: An Antidote to Chaos
# 416                                                1984
# 418                                                1984
# 786                                                1984
# 1760                                               1984
# 1694                                               1984
# 1749                                               1984
# 747   A Beginner's Guide to the Stock Market: Everyt...
# 1466  A Beginner's Guide to the Stock Market: Everyt...
# 299              A Breath of Snow and Ashes (Outlander)
# 397              A Breath of Snow and Ashes (Outlander)
# 2241                                  A Christmas Carol
# 1274                                  A Christmas Carol
# 2196                        A Court of Thorns and Roses
# 1248                        A Court of Thorns and Roses
# 2016                        A Court of Thorns and Roses
# 1099                   A Gambling Man (An Archer Novel)
# 1098                   A Gambling Man (An Archer Novel)
# 2072                     A Gentleman in Moscow: A Novel
# 123                      A Gentleman in Moscow: A Novel
# 565                      A Gentleman in Moscow: A Novel
# 2078                     A Gentleman in Moscow: A Novel
# 1514                   A Long Petal of the Sea: A Novel

# %% [markdown]
# It seems that the duplicates have quite similar values for all columns. What we found noteworthy:
# 1. The prices with missing values differ between duplicates.
# 2. Categories are not equal between duplicates.
#
# We are curious why those duplicates happened and our first hunch on what could be useful is l

# %%
amazon_books_updated[amazon_books_updated.duplicated(subset=['title'], keep=False)]["title"]
amazon_books_updated[amazon_books_updated["title"] == "Pretty Girls"]
# Out:
#                                                   brand  \
# 11                                      Karin Slaughter
# 2036  Karin Slaughter (Author), Kathleen Early (Narr...
#
#                                              categories  \
# 11    ["Books","Mystery, Thriller & Suspense","Thril...
# 2036  ["Books","Mystery, Thriller & Suspense","Myste...
#
#                                                  format hardcover_price  \
# 11    [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $37.70
# 2036  [{'name': 'Kindle', 'price': '$9.99', 'url': '...          $37.68
#
#      kindle_price mass_market_paperback_price paperback_price  \
# 11          $9.99                         NaN           $7.98
# 2036        $9.99                       $9.99           $7.99
#
#      perfect_paperback_price              rating  reviews_count         title
# 11                       NaN  4.3 out of 5 stars          10050  Pretty Girls
# 2036                     NaN  4.3 out of 5 stars          10050  Pretty Girls

# %% [markdown]
# ## References

# %% [markdown]
# https://en.wikipedia.org/wiki/Hardcover
#
# https://www.julesbuono.com/paperback-vs-mass-market-paperback/
#
# https://en.wikipedia.org/wiki/Paperback#Mass-market
#
# https://en.wikipedia.org/wiki/Amazon_Kindle
#
# https://sellercentral.amazon.com/forums/t/what-is-a-perfect-paperback-in-listing-a-book/236479
#
# https://en.wikibooks.org/wiki/Bookbinding/Perfect_binding
